# %%
import pandas as pd

# %%
df = pd.read_csv('./data/Petitions.csv')
df
# Out:
#             id                               public_petition_text  \
# 0      3168490                                     снег на дороге
# 1      3219678                очистить кабельный киоск от рекламы
# 2      2963920  Просим убрать все деревья и кустарники, которы...
# 3      3374910  Неудовлетворительное состояние парадной - надп...
# 4      3336285                                           Граффити
# ...        ...                                                ...
# 59884  3128111                           прошу закрасить граффити
# 59885  3276713       Прошу вас отремонтировать пешеходную дорожку
# 59886  3274663  Необходимо демонтировать незаконную рекламную ...
# 59887  3359308  Очень гремит на ветру металлическая часть окна...
# 59888  3209098  Две проблемы в одном:\n1) Незаконные надписи/о...
#
#                                          reason_category
# 0                                        Благоустройство
# 1                                        Благоустройство
# ...

# %%
n = 0
for i in df['reason_category'].unique():
    n += 1
    print(n, i)
# Out:
# 1 Благоустройство
# 2 Содержание МКД
# 3 Незаконная информационная и (или) рекламная конструкция
# 4 Фасад
# 5 Водоснабжение
# 6 Нарушение правил пользования общим имуществом
# 7 Повреждения или неисправность элементов уличной инфраструктуры
# 8 Кровля
# 9 Состояние рекламных или информационных конструкций
# 10 Нарушение порядка пользования общим имуществом
# 11 Подвалы
# 12 Водоотведение
# 13 Санитарное состояние
# 14 Центральное отопление
# 15 Незаконная реализация товаров с торгового оборудования (прилавок, ящик, с земли)
